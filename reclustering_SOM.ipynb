# %% [markdown]
# ### Imports et initialisations

# %%
import numpy as np
# Pour l'échantillonnage aléatoire
import random
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from clustertools import *
import os
import gc

# %%
clean_method = "Lem"
clust_method = "som_225"

#répertoire dans lequel seront stockés les clusters, doit se terminer obligatoirement par /
clusters_dir = "clusters/1M_{}_clusters/{}/".format(clean_method, clust_method)
clusters_save_dir = clusters_dir + "a_reclustering_som/"

# %% [markdown]
# ### Chargement des données en mémoire

# %%
clean_clusters, raw_clusters, two_dim_clusters = load_clusters(clusters_dir)

# %%
len(clean_clusters[1])
# Out:
# 82496

# %% [markdown]
# ### Encodage du jeu de données
#
# On charge le modèle depuis le disque

# %%
from gensim.models import KeyedVectors

# %%
model = KeyedVectors.load("models/w2vec_model_d300_1M_{}".format(clean_method))
dim = 300

# %%
# Encode un message
# msg : liste de chaînes de caractères correspondant aux mots du message
# model : le modèle utilisé pour l'encodage
# dim : la dimension des vecteurs mots dans ce modèle
# Renvoie un vecteur qui est la moyenne de tous les vecteurs correspondants aux mots du message
# Si aucun mot du message n'est dans le modèle, renvoie un vecteur de zéros.
def encode(msg, model, dim):
    return np.mean([model[word] for word in msg if word in model] or [np.zeros(dim)], axis = 0)

# %%
# %%time
#encodage des clusters
encoded_clusters = [np.array([encode(msg, model, dim) for msg in cluster]) for cluster in clean_clusters]
# Out:
# CPU times: user 20.2 s, sys: 0 ns, total: 20.2 s
# Wall time: 20.2 s

# %% [markdown]
# ### SOM

# %%
from minisom import MiniSom

# %%
if not os.path.exists(clusters_save_dir):
    os.mkdir(clusters_save_dir)

# %%
# %%time
for i, (enc_cluster, clean_cluster, raw_cluster, two_dim_cluster) in enumerate(zip(encoded_clusters, clean_clusters, raw_clusters, two_dim_clusters)):
    init_globals(clean_cluster, raw_cluster, two_dim_cluster, clusters_save_dir + "_{}".format(i))
    som_model = MiniSom(3, 4, 300, neighborhood_function='gaussian', random_seed=0)
    som_model.pca_weights_init(enc_cluster)
    som_model.train(enc_cluster, 10000, verbose=True)    
    som_pred = []
    for msg in enc_cluster:
        winner = som_model.winner(msg)
        som_pred.append(winner[0]*4+winner[1])  
    centroids = []
    for row in som_model.get_weights():
        for w in row:
            centroids.append(w)
    som_centers = [[r[0] for r in model.similar_by_vector(c)] for c in centroids]
    #parse_result(som_pred, 'som_{}'.format(n_clust), som_centers)
    #show_hate_clusters(som_pred, som_centers)
    wlists, mlists, cmlists, e2dmlists, mfw, hkw, clust_n_msg = parse(som_pred)
    cluster_number_printed = False
    for j in range(len(clust_n_msg)):
        if (hkw[j][1] > 5):
            if not cluster_number_printed:
                cluster_number_printed = True
                print("Cluster {}:".format(i))
            print("Sous-cluster {} : {} messages".format(j, clust_n_msg[j]))
            print("{} messages contiennent un mot-clé haineux (soit {:.2f}%)".format(hkw[j][0], hkw[j][1]))
            print("Les {} mots les plus fréquents :".format(len(mfw[j])), end=' ')
            for word in mfw[j]:
                print(word, end=' ')
            print("\nLes mots les plus proches du centre :", end = ' ')
            for w in som_centers[j]:
                print(w, end=' ')
            print('\n')
            save_cluster_raw_msg(mlists[j], clusters_save_dir + "_cluster_{}.{}_raw_msg_{:.2f}pch".format(i,j, hkw[j][1]))
            with open(clusters_save_dir + "_subclusters_info.txt", "a") as f:
                f.write("Cluster {}, sous-cluster {} : {} messages\n".format(i, j, clust_n_msg[j]))
                f.write("{} messages contiennent un mot-clé haineux (soit {:.2f}%)\n".format(hkw[j][0], hkw[j][1]))
                f.write("Les {} mots les plus fréquents : ".format(len(mfw[j])))
                for word in mfw[j]:
                    f.write(word + ' ')
                f.write("\nLes mots les plus proches du centre : ")
                for w in som_centers[j]:
                    f.write(w + ' ')
                f.write('\n\n')
    if cluster_number_printed:
        print()

# %%
def recluster():
    for i, (enc_cluster, clean_cluster, raw_cluster, two_dim_cluster) in enumerate(zip(encoded_clusters, clean_clusters, raw_clusters, two_dim_clusters)):
        init_globals(clean_cluster, raw_cluster, two_dim_cluster, clusters_save_dir + "_{}".format(i))
        som_model = MiniSom(3, 4, 300, neighborhood_function='gaussian', random_seed=0)
        som_model.pca_weights_init(enc_cluster)
        som_model.train(enc_cluster, 10000, verbose=True)    
        som_pred = []
        for msg in enc_cluster:
            winner = som_model.winner(msg)
            som_pred.append(winner[0]*4+winner[1])  
        centroids = []
        for row in som_model.get_weights():
            for w in row:
                centroids.append(w)
        som_centers = [[r[0] for r in model.similar_by_vector(c)] for c in centroids]
        #parse_result(som_pred, 'som_{}'.format(n_clust), som_centers)
        #show_hate_clusters(som_pred, som_centers)
        wlists, mlists, cmlists, e2dmlists, mfw, hkw, clust_n_msg = parse(som_pred)
        cluster_number_printed = False
        for j in range(len(clust_n_msg)):
            save_cluster_raw_msg(mlists[j], clusters_save_dir + "cluster_{}.{}_raw_msg_{:.2f}pch".format(i,j, hkw[j][1]))
            if (hkw[j][1] > 5):
                if not cluster_number_printed:
                    cluster_number_printed = True
                    print("Cluster {}:".format(i))
                print("Sous-cluster {} : {} messages".format(j, clust_n_msg[j]))
                print("{} messages contiennent un mot-clé haineux (soit {:.2f}%)".format(hkw[j][0], hkw[j][1]))
                print("Les {} mots les plus fréquents :".format(len(mfw[j])), end=' ')
                for word in mfw[j]:
                    print(word, end=' ')
                print("\nLes mots les plus proches du centre :", end = ' ')
                for w in som_centers[j]:
                    print(w, end=' ')
                print('\n')
                with open(clusters_save_dir + "subclusters_info.txt", "a") as f:
                    f.write("Cluster {}, sous-cluster {} : {} messages\n".format(i, j, clust_n_msg[j]))
                    f.write("{} messages contiennent un mot-clé haineux (soit {:.2f}%)\n".format(hkw[j][0], hkw[j][1]))
                    f.write("Les {} mots les plus fréquents : ".format(len(mfw[j])))
                    for word in mfw[j]:
                        f.write(word + ' ')
                    f.write("\nLes mots les plus proches du centre : ")
                    for w in som_centers[j]:
                        f.write(w + ' ')
                    f.write('\n\n')
        if cluster_number_printed:
            print()  
        gc.collect()

# %%
# %%time
clusters_dir = "clusters/1M_Lem_clusters/"

for method in ["km_25", "km_50", "km_100", "som_100", "som_225", "som_400"]:
    print("Clustering des clusters {}\nChargement des clusters en mémoire.".format(method))
    clean_clusters, raw_clusters, two_dim_clusters = load_clusters(clusters_dir + method + '/')
    print("Encodage des clusters")
    encoded_clusters = [np.array([encode(msg, model, dim) for msg in cluster]) for cluster in clean_clusters]
    clusters_save_dir = clusters_dir + method + "/a_reclustering_som/"
    if not os.path.exists(clusters_save_dir):
        os.mkdir(clusters_save_dir)
    recluster()
    print()
# Out:
# Clustering des clusters km_25
# Chargement des clusters en mémoire.
# Encodage des clusters
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1165662920495003
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.395496645925121
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9664969084258203
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.6282865153648953
# /home/victor/data/fidle/fidle-env/lib/python3.9/site-packages/minisom.py:379: ComplexWarning: Casting complex values to real discards the imaginary part
#   self._weights[i, j] = c1*pc[pc_order[0]] + c2*pc[pc_order[1]]
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7270758893941067
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3123805338472496
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4408674805139372
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.7659576236009624
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7941994788648851
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.6018742675873123
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3318916102642067
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4243316806203878
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.7319796595246781
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.343476732928684
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4618377382924728
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8915912110168807
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.194258865032134
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.7049264909841966
# Cluster 17:
# Sous-cluster 6 : 3144 messages
# 329 messages contiennent un mot-clé haineux (soit 10.46%)
# Les 20 mots les plus fréquents : pute chien couille gueul merde fdp mère casse tête fil cul bordel rage niqu ferme rat bâtard bais chier encul
# Les mots les plus proches du centre : tmr clebard timp pvt zgeg vibreur tahan geul bdg purer.
#
# Sous-cluster 11 : 882 messages
# 54 messages contiennent un mot-clé haineux (soit 6.12%)
# Les 20 mots les plus fréquents : pute merde rat cul fdp malade porc coup salope chien fils mort coeur dinguerie menteur csc tête sein ferme crâne
# Les mots les plus proches du centre : gros salope, renifler cheh purer. zgeg lstb xptdrrrrrrrr geul calvitie
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.390458523330449
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0944406759467908
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.04325332028129779
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.6520273952692262
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4163060067527264
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.6218830065777219
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.666556153103617
#
# Clustering des clusters km_50
# Chargement des clusters en mémoire.
# Encodage des clusters
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.039933821154711294
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5250133375137973
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.78536979322315
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3116884025631441
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1491517294291824
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3027733598033961
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.7763477494512674
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3947928454635417
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3197760460014312
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1740941594836227
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5956183484789994
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.0033700631009480815
# /home/victor/data/fidle/fidle-env/lib/python3.9/site-packages/minisom.py:513: RuntimeWarning: invalid value encountered in sqrt
#   return sqrt(-2 * cross_term + input_data_sq + weights_flat_sq.T)
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.563559618929798
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5198528748453457
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1025173882069383
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5554101854738638
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9370673984734575
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5672241400018763
# Cluster 17:
# Sous-cluster 4 : 1315 messages
# 68 messages contiennent un mot-clé haineux (soit 5.17%)
# Les 20 mots les plus fréquents : merde pute énorme tête cul con coup chien problème ferme rat petit porc gueul prendre mort fdp malade putain coeur
# Les mots les plus proches du centre : gros salope, mouv gargantuesque ptt renifler desole lstb miett incroyable!!!!!!!!!!
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.2845137864625587
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.708539534979025
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1227916851024575
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1344172073960685
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3218310073371462
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7624403567315228
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.30766798744635904
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3926065898807145
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.5736482168459478
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5213115574259364
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3745248420753193
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.394895165766831
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2785236015196995
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3426057761296588
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5458521446265066
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5801813382438137
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.164906923006925
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2454581134227802
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2762090755136446
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3283697466684972
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.959101683796682
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2917122172354707
# Cluster 39:
# Sous-cluster 7 : 39 messages
# 2 messages contiennent un mot-clé haineux (soit 5.13%)
# Les 20 mots les plus fréquents : devenu?! qu’ref vachanse bugou? banoit ba'di nagnonotif bonnie3404 gnit3 jleg bat,,,!!!!! remarqu! coclé haujalini hijbé decapotabl davs patdarux bugeo? russelfnt
# Les mots les plus proches du centre : twitter twitter, twitter. facebook, space! unfollow twitter? fak instagram, reposter
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5986768900629595
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1132852966380644
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3521457796196468
# Cluster 42:
# Sous-cluster 1 : 280 messages
# 16 messages contiennent un mot-clé haineux (soit 5.71%)
# Les 20 mots les plus fréquents : niqu parent niquer femme mere âge époque fou croire envie stp ferme ' ptdr pèr arrière wallah mieux mdrrr appeler
# Les mots les plus proches du centre : cousin, foutoir qu’bais daron, grand tropmon quesqu niquez baisez filme.
#
# Sous-cluster 6 : 35 messages
# 2 messages contiennent un mot-clé haineux (soit 5.71%)
# Les 20 mots les plus fréquents : bouche cerveau gueule rouge pont ressemble règlement compte qu’qu’bel vic, leçon doublepensé novlangu orwelien usage nombre. mot idée. il vire
# Les mots les plus proches du centre : grand grand-mèr, soeur! prise, qu’grand foutoir magique! rigolo, constamment, plisser
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5832271155684807
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.451939255839427
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.6164444373886842
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3544113095157313
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4713297059378676
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.0399019846634141
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.24644085542129
#
# Clustering des clusters km_100
# Chargement des clusters en mémoire.
# Encodage des clusters
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4260007211770365
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0210056101625287
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3568508162098867
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.033945445647025126
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.2127988595535177
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.26377692734447
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.344533943569015
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.444613373933465
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.320611117232972
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1020264390956234
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4192408894790474
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4325806478243834
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2070596121661024
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4770636871950744
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.644663508871215
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7435216176701872
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.257938645668723
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2887714151635898
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.139505062152033
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0934334150679184
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8778856463283993
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4879252664999527
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3172494979566212
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3113919510731742
# Cluster 23:
# Sous-cluster 2 : 32 messages
# 2 messages contiennent un mot-clé haineux (soit 6.25%)
# Les 20 mots les plus fréquents : toucher remplir médusa briser. distraction. grave fière moindre tendre bonheur sucr -lo undisputed main tarlouze barca club gé pétard participer
# Les mots les plus proches du centre : petit p’tit soeur! pincement coeur? miett chant, habit, tendre. petit!
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2769856083564788
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3471559960086554
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2523909066948862
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5479724803591455
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.28021503315466334
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8407082601362577
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3728328066788085
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0804604295065237
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4839900563844182
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5619345184584603
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.47758035405117033
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7701261404741846
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4455762932479763
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.024120824296521792
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1149532225248762
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.055753346317248
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.687492517803998
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3325933874824758
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0940388268120607
# Cluster 42:
# Sous-cluster 7 : 17 messages
# 1 messages contiennent un mot-clé haineux (soit 5.88%)
# Les 20 mots les plus fréquents : = aavafzmdl6 #stiklaleyürütürkiyehttps//twitter.com drjohnb2 status/1459961613864349707?t vrxtgj58yzy5cij0sgwqq&amp;s=19 ttps//www.pinterest.e pin/684124999654676182/ oligarch billionaireadministration regimetomato tomato quote 14https//t.co a0y09pnugp eternalcourage e pdg exprim! réveil
# Les mots les plus proches du centre : / sur https//t.co lon testlat delta affecté ygqibk4mbohttps//t.co périmètr sec
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3111142409715963
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9014455699771863
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3233801912834622
# Cluster 45:
# Sous-cluster 0 : 168 messages
# 12 messages contiennent un mot-clé haineux (soit 7.14%)
# Les 20 mots les plus fréquents : rir mort mdrrrr dinguerie jsuis jur ouai .. mdrr grave omg sah wsh vrmt csc jt pleure ptn clochard tkt
# Les mots les plus proches du centre : gros lstb xptdrrrrrrrr talheur renifler salope, wllh ahahahahah purer. tmr
#
# Sous-cluster 3 : 289 messages
# 18 messages contiennent un mot-clé haineux (soit 6.23%)
# Les 20 mots les plus fréquents : dossier fils #tpmp soir vidéo live jeu petit matin fil chat terre amphi côté sortir heureusement mort regarder visage mytho
# Les mots les plus proches du centre : salope, renifler contredis qu’niqu waaaaa pnj poto?? mouv talheur dler
#
# Sous-cluster 10 : 33 messages
# 4 messages contiennent un mot-clé haineux (soit 12.12%)
# Les 20 mots les plus fréquents : homme = libérer 2 salope peine français 35h, lieu 32h. problème,-ce? dispute vacciné vacciner. risque thombose utiliser france cheveux poste
# Les mots les plus proches du centre : gros salope, mouv gargantuesque 50ans renifler qu’niqu m’veux dler troue
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1569161676882764
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0391755953730317
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5191241431928821
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.28445420507005204
# Cluster 49:
# Sous-cluster 4 : 17 messages
# 1 messages contiennent un mot-clé haineux (soit 5.88%)
# Les 20 mots les plus fréquents : mort gab humongou demaissss claire ch caralh mdssss vem oiseau conseiller retraité adorable cutie lyla #adorable #cat#catlover #thelylacat # ent
# Les mots les plus proches du centre : * noell! boochie deuzolivre conhaqu envrer destroyer666 dangle *, favour
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1131571514051415
# Cluster 50:
# Sous-cluster 0 : 24 messages
# 3 messages contiennent un mot-clé haineux (soit 12.50%)
# Les 20 mots les plus fréquents : fils pute france criminel? pédos enflure meurtrier! allez inshallah rétabli supplic brodequin? désoler violeur qu’mettre perpétuité revenir condamnation genr homme
# Les mots les plus proches du centre : mort peine mort? alourdir mort, perpétuité suicid, dévasté mort. apostasier
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4355050101571458
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3023612727297418
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3090626954342732
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.7284844355677678
# Cluster 54:
# Sous-cluster 3 : 3219 messages
# 305 messages contiennent un mot-clé haineux (soit 9.47%)
# Les 20 mots les plus fréquents : menteur salope méchant génie raciste encul hypocrite bouche rat connard mendy honteux gueule suceur dégoût bais dégage culot espèce ferland
# Les mots les plus proches du centre : clebard tahan encule, zgeg bdg égout qu’retourn ahahahahahah merdeux babtou
#
# Sous-cluster 10 : 308 messages
# 162 messages contiennent un mot-clé haineux (soit 52.60%)
# Les 20 mots les plus fréquents : niqu fils mèr bais pue grand père mere grand-mère racont bz pèr fille niquer eren pleure salle tante truc part
# Les mots les plus proches du centre : mère pute. pute, pvte pute daron, qu’bais pute? p*te baisez
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4638860343254567
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.0007008430588993661
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3316111361867564
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.33316106597649575
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4400403942027231
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1484482041607422
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.2620927215538097
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9497141158768305
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.350313370940693
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.252688726800829
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2837819385099216
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3538987708779342
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2757377800913918
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2206547014861096
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9610297825793607
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.322118990864
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2558987468596914
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.7323868592350682
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.01061548441489133
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0058162596065778
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5864915819672494
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.2780057797190546
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4345441545217814
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.515120991678862
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3940203580843322
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1630126179057967
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.258204889006788
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.222050395631859
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2226816715735354
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4079769162065112
# Cluster 84:
# Sous-cluster 4 : 246 messages
# 13 messages contiennent un mot-clé haineux (soit 5.28%)
# Les 20 mots les plus fréquents : only tcg celebration store #ad buy 19.99 pokemon locations vary box #pokemongofriend diamond #pokemongo i delux pin #pokemongofriendcod brillier #pokemongoraid
# Les mots les plus proches du centre : let'be diamond go! unite pearl shining celebration yourself brillier paradise
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2915755262845439
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1327006987345127
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8143609020895788
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9761545682353933
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3864393985365273
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.12511157996882658
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0937089156418067
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3768167659121004
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3831114432844385
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3352422831552904
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3664724532592016
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3879378442383274
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3679350059387017
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.220689936968184
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2374193229501314
#
# Clustering des clusters som_100
# Chargement des clusters en mémoire.
# Encodage des clusters
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3276190845827716
# Cluster 0:
# Sous-cluster 8 : 30 messages
# 2 messages contiennent un mot-clé haineux (soit 6.67%)
# Les 20 mots les plus fréquents : toucher remplir médusa briser. distraction. grave meilleur fière moindre tendre bonheur sucr -lo undisputed main tarlouze barca club mone ....
# Les mots les plus proches du centre : petit p’tit pincement soeur! miett coeur? bambou chant, petit! habit,
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1581973349512251
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3733410239271333
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4296979225933442
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9648052818517839
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.439917750438911
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.421975516406515
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3405217280170747
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3236393582174641
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1802974339030907
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1021748224936292
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8506266386443077
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.239290574364171
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5285192029546228
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5719709881030148
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5865376746575797
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.396547563667356
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2896571166864879
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2407504832135179
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2709683563797993
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4798472030538172
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4020131129838922
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1743818254791059
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.258901106133235
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.009817483634005
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.25074310598477
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3042178507966393
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2405563702218398
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2073546743181824
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1567021529000296
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.107834156940256
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2995312108004575
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4394360422676682
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2940345093487564
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9376914132708994
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2815949816183148
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2745543748863706
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2623887573524242
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4012597771406454
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.26859783773258
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2153159360754957
# Cluster 40:
# Sous-cluster 7 : 21 messages
# 2 messages contiennent un mot-clé haineux (soit 9.52%)
# Les 20 mots les plus fréquents : user démarr #live #deadbydaylight! manqu aavafzmdl6 #stiklaleyürütürkiyehttps//twitter.com drjohnb2 status/1459961613864349707?t vrxtgj58yzy5cij0sgwqq&amp;s=19 ttps//www.pinterest.e pin/684124999654676182/ oligarch billionaireadministration regimetomato tomato quote 14https//t.co a0y09pnugp eternalcourage
# Les mots les plus proches du centre : / sur https//t.co lon testlat delta affecté ygqibk4mbohttps//t.co périmètr 7.612919,38.685897
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2877565542157783
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4388078894510397
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3248451346497576
# Cluster 43:
# Sous-cluster 0 : 15 messages
# 1 messages contiennent un mot-clé haineux (soit 6.67%)
# Les 17 mots les plus fréquents : garde saligaut gouiner hoseok smill layout volé tn sauterne moliner rapprocher?! boug danger diane. #cétoute #caughtmewayoffguardfencing toucans-en
# Les mots les plus proches du centre : garde précieusement pogner nu. rouler, rapproché sauce, bébé? servie qu’profitent
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4512314054667135
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2798981656120245
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.1091380372185468
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2616030782264824
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1886050774931316
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2609603493962889
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5780170032866372
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3607686670229275
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3537943105951522
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2665072031296771
# Cluster 53:
# Sous-cluster 0 : 38 messages
# 2 messages contiennent un mot-clé haineux (soit 5.26%)
# Les 20 mots les plus fréquents : devenu?! qu’ref vachanse bugou? banoit ba'di nagnonotif bonnie3404 gnit3 jleg bat,,,!!!!! remarqu! coclé haujalini hijbé decapotabl davs patdarux bugeo? russelfnt
# Les mots les plus proches du centre : twitter twitter, twitter. facebook, unfollow space! twitter? fak reposter tweets
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.638013071243034
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1363384601457585
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1542187602718905
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1975603325710478
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.187006621736787
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3259660816964483
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.6040835258434658
# Cluster 60:
# Sous-cluster 2 : 120 messages
# 14 messages contiennent un mot-clé haineux (soit 11.67%)
# Les 20 mots les plus fréquents : mère niqu pute mèr bais pue grand mere bz pèr niquez chatte grand-mère respecter dégueulasse poto jfume chit lèvre gercée
# Les mots les plus proches du centre : mère daron, tmr p*te qu’bais timpe pvte mioche tej pute?
#
# Sous-cluster 9 : 1308 messages
# 82 messages contiennent un mot-clé haineux (soit 6.27%)
# Les 20 mots les plus fréquents : chier pute casse bâtard suceur encul bouche bz gueul foutr pue fume mody ntm pet caca ftg foutre sal casser
# Les mots les plus proches du centre : tmr zgeg xptdrrrrrrrr ahahahahah mdddrr ahahahahahah mdrrrrrrrrrr mdddrrr degage tahan
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.52368788541372
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4631240644877364
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4431136454204208
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5466392149449952
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0116541660521914
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.6887790270423928
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4189279037663012
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.4116369701185691
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.501379093364396
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3062787509685991
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0759063716368
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2709914685201211
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.61521249244457
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3279178430737346
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.221959891901797
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5903034029754528
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3723679684980843
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3735125937730284
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4383439993624894
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3286054567645242
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.39470133692708
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4061992892146593
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.589229190009414
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2974573348806933
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2640244055312089
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4072097555141692
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1683816587835671
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3670934262837382
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5280599998554716
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3453676810738049
# Cluster 90:
# Sous-cluster 3 : 603 messages
# 68 messages contiennent un mot-clé haineux (soit 11.28%)
# Les 20 mots les plus fréquents : merd band grosse meuf couille jsuis space rir tweet mère sacrer vie fils #spaceafrooo club mdrr savoir monde sein parler
# Les mots les plus proches du centre : salope, renifler lstb mdrrr? purer. desole contredis tmr talheur mouv
#
# Sous-cluster 9 : 69 messages
# 65 messages contiennent un mot-clé haineux (soit 94.20%)
# Les 20 mots les plus fréquents : fils band #porto #rendnousleuro #smooth lfil fisl grosse espèce tht ad thibs mère ayton peux frang-clair geule troll? arnaqu cok
# Les mots les plus proches du centre : pute pute. pvte pute, pute? timp p*te salope tchoin tapin
#
# Sous-cluster 10 : 97 messages
# 12 messages contiennent un mot-clé haineux (soit 12.37%)
# Les 20 mots les plus fréquents : fraude vieux qu’leaker fragile gosse bouffon traire blinder fouu balance mmmdrrr bienn pvt aulas charla? boulot juif! 24n entonce?? tocard!
# Les mots les plus proches du centre : sale pvte pute merdeux clebard pute, pute. p*te tchoin crasseux
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.300659805987736
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.160902710833387
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.121708002104905
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1937841129400966
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8517863211740754
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0428944092545147
# Cluster 96:
# Sous-cluster 3 : 27 messages
# 2 messages contiennent un mot-clé haineux (soit 7.41%)
# Les 20 mots les plus fréquents : bande pute band race mineur gueul pv mdrrrr dégage supprimé croire moment m’démoraliser m’enlever sourire st arreter tirer martiniquais grand
# Les mots les plus proches du centre : con merdeux arrete clebard blaireal weeb matrixe bdg chauve. otn
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3066180147404844
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.37963551896602893
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.12068434283801548
#
# Clustering des clusters som_225
# Chargement des clusters en mémoire.
# Encodage des clusters
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.034915669413565
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2910463724416519
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2464950861500868
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1134522803196052
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.024783047643009974
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.47455672438089824
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.100222856219124
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3083478376409048
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.22841242730779662
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7849223521531672
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3054938538405205
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.28445420507005204
# Cluster 11:
# Sous-cluster 4 : 17 messages
# 1 messages contiennent un mot-clé haineux (soit 5.88%)
# Les 20 mots les plus fréquents : mort gab humongou demaissss claire ch caralh mdssss vem oiseau conseiller retraité adorable cutie lyla #adorable #cat#catlover #thelylacat # ent
# Les mots les plus proches du centre : * noell! boochie deuzolivre conhaqu envrer destroyer666 dangle *, favour
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2242685592549094
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.138652760721971
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8077790543936334
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3364048508689608
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.300308625068484
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1616131001148966
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.188064170831567
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1999078747329641
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.23068377050361535
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2495197813247338
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.48876535201869986
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.175555280336915
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.35686036129475
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1416448276765336
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7731433130367714
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7894466027879637
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2877164131503336
# Cluster 28:
# Sous-cluster 5 : 16 messages
# 1 messages contiennent un mot-clé haineux (soit 6.25%)
# Les 9 mots les plus fréquents : 94eme lâche. solary-débriefread catastrophique follass mec.???? aimer plaire rer
# Les mots les plus proches du centre : quitte quitter invivable déménager lyon? brailler jma mtp démolir assur
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1153137900780248
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0054414409596062
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3223933109995403
# Cluster 31:
# Sous-cluster 5 : 16 messages
# 1 messages contiennent un mot-clé haineux (soit 6.25%)
# Les 10 mots les plus fréquents : hâter termine décembre?! dur décembre! lupdat janvier septembre finit vivement
# Les mots les plus proches du centre : mois mois, mois? mois! mois. janvier, novembr. mois?? août. 5/6
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1172422096694068
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.169185493215543
# Cluster 33:
# Sous-cluster 0 : 8 messages
# 1 messages contiennent un mot-clé haineux (soit 12.50%)
# Les 7 mots les plus fréquents : tootatis racaill. cz zeribi. raipubliqeuuuuu fou? mauvais
# Les mots les plus proches du centre : rendre argent rend rendra qu’rendre arger rendent argent! qu’rend argent.
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1601484060690395
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2846531292120758
# Cluster 35:
# Sous-cluster 2 : 441 messages
# 35 messages contiennent un mot-clé haineux (soit 7.94%)
# Les 20 mots les plus fréquents : rat ferme fils malade sein mdrrrr gueule grave csc sale connard ouai mdrr jsuis bouffon mytho gueul jur salope vien
# Les mots les plus proches du centre : gros renifler salope, cheh tmr geul purer. lstb talheur cetai
#
# Sous-cluster 9 : 527 messages
# 31 messages contiennent un mot-clé haineux (soit 5.88%)
# Les 20 mots les plus fréquents : banger space fil sale #tpmp mdrr jsuis #spaceafrooo caca mal 2 lâche franchement dis dinguerie aime petit meuf entendre attend
# Les mots les plus proches du centre : salope, renifler mouv lstb talheur ptt qu’niqu qu’retourn contredis jurer!
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1065471569908594
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1799151692423673
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4404428308357504
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0745291012718459
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0989278582085888
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2950445407509574
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1450641013327139
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2377456689035915
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2277087699806337
# Cluster 44:
# Sous-cluster 0 : 38 messages
# 2 messages contiennent un mot-clé haineux (soit 5.26%)
# Les 20 mots les plus fréquents : devenu?! qu’ref vachanse bugou? banoit ba'di nagnonotif bonnie3404 gnit3 jleg bat,,,!!!!! remarqu! coclé haujalini hijbé decapotabl davs patdarux bugeo? russelfnt
# Les mots les plus proches du centre : twitter twitter, twitter. facebook, space! unfollow twitter? fak instagram, reposter
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.5915725817294079
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9649480615712331
# Cluster 46:
# Sous-cluster 10 : 12 messages
# 1 messages contiennent un mot-clé haineux (soit 8.33%)
# Les 20 mots les plus fréquents : #stiklaleyürütürkiyehttps//twitter.com drjohnb2 status/1459961613864349707?t vrxtgj58yzy5cij0sgwqq&amp;s=19 oligarch billionaireadministration regimetomato tomato quote 14https//t.co a0y09pnugp eternalcourage e pdg exprim! réveil coeurshttps//t.co ws986fvb1nhttps//t.co boxnbmldw4 market//details?id
# Les mots les plus proches du centre : / sur lon https//t.co testlat delta affecté mindice uv pression
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2251339192630333
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.6904876537280925
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1278752228809816
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.439594216183842
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1048197978000884
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4380280703866737
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.337023911420593
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3008093508872351
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.276151762780949
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3447648662322473
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.766822731255255
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2517334395482473
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2360827062597146
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.479248732273029
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.108283128422254
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.6128157858194618
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.18298440524154
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3357681766831688
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0894995396760023
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0789345911917119
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2359313296403984
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8492818775608019
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2446444436700268
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9322923116995169
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9875712964564648
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9301915332081768
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3001020618174248
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2807272500239375
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1762179061846885
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.046094004556767154
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1839136199761637
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0463098114224334
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.054587562429405455
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0037747399893484
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.291288755870425
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7781423775170763
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.191832990061543
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3186371824076732
# Cluster 84:
# Sous-cluster 8 : 51 messages
# 4 messages contiennent un mot-clé haineux (soit 7.84%)
# Les 20 mots les plus fréquents : pute pue pèr femme, ps ensemble akhy goûter chien cancalais? caractèr! . fil amen!!! voyon bébé krkrkrkr stresse niquer parle
# Les mots les plus proches du centre : grand qu’bais fils, baisez enterrement. cousin, tapin père. qu’grand niquez
#
# Sous-cluster 10 : 137 messages
# 7 messages contiennent un mot-clé haineux (soit 5.11%)
# Les 20 mots les plus fréquents : macron prix gagnant sécu riche, quinquennat .... projet bla achat perdant victoire pauvre, anner radio décryptage cliver voleur brésil. marionnette
# Les mots les plus proches du centre : important? oligarque bouse .mêm comptait smicard choisissent vain, habité franceet
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1774504576970808
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3275297811374749
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4594860163795251
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.203190610327738
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4696744943061615
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1878279901862505
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2479099742186162
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1685715441454576
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3530765226079287
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7203970172392937
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1966052867877328
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.283085096105304
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.349754927387071
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9477860564936667
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.53172645511208
# Cluster 99:
# Sous-cluster 0 : 76 messages
# 8 messages contiennent un mot-clé haineux (soit 10.53%)
# Les 20 mots les plus fréquents : pue pleure poisson va-niqu viell dégommer! jur détest m’foutisme flemmardis baiser porte lhaun fliiiip daron dhdhq niquez attrape blanquer butte!
# Les mots les plus proches du centre : mère mere mère, qu’bais daron, tante mère. p*te mèr baisez
#
# Sous-cluster 8 : 166 messages
# 23 messages contiennent un mot-clé haineux (soit 13.86%)
# Les 20 mots les plus fréquents : gosse fraude mdrrr connard fai riche cancer noir?? porc vieux ntm moche pvt hypocrite fille détest espèce tomber ptdr chien
# Les mots les plus proches du centre : sale pvte pute clebard p*te pute. tchoin pute, merdeux timp
#
# Sous-cluster 9 : 129 messages
# 111 messages contiennent un mot-clé haineux (soit 86.05%)
# Les 20 mots les plus fréquents : re inventer pute. chui regard mere #porto #rendnousleuro #smooth solitude essayer défendre lfil génération maurice? , pote, fisl grosse caca
# Les mots les plus proches du centre : pute pute. pvte pute, fils pute? fil p*te timp tapin
#
# Sous-cluster 10 : 547 messages
# 158 messages contiennent un mot-clé haineux (soit 28.88%)
# Les 20 mots les plus fréquents : mèr mere retourn sal niquer ntm ftg pleure frappe pue suce baiser ptdr parl race chien meuf ptdrrr daronn jsp
# Les mots les plus proches du centre : pvte tmr zgeg p*te bdg ahahahahahah timp clebard tchoin timpe
#
# Sous-cluster 11 : 46 messages
# 4 messages contiennent un mot-clé haineux (soit 8.70%)
# Les 20 mots les plus fréquents : mendy ferland moliner romain #spacemoliner couill kenza mendy, buzz footeux ptdddr vien sauc foot culotter alzote taper prénom con prison
# Les mots les plus proches du centre : zgeg fff. pointeur mouliner dembel lache nwar salope, qu’balancer hahahahahaha
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.295677479361987
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9858524491283673
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.552083553257558
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1732021151344132
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.381974409121364
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5098201540627976
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7131854278266238
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4066824867933476
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4625800591812588
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8527217680913183
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2378105760787177
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.193110179554306
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1736714388259173
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.135345845552269
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7475354812490181
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1622610436349967
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1501983617708862
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2429709905505955
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.6610723771706166
# ...
#  quantization error: 1.0516406681975066
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2871606773802926
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1853966273270775
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2137225360467536
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1846107533250658
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0892859297163953
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0744611036660772
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2204870385143212
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.273427538047331
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2398044094093206
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1912261252457281
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2437659645247032
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0098811425140295
# Cluster 277:
# Sous-cluster 11 : 15 messages
# 1 messages contiennent un mot-clé haineux (soit 6.67%)
# Les 20 mots les plus fréquents : suceur raciste. négre biiiennn cqu gisel ! qu’coupent femme. bassem arabe beur, noir nword neptune bieeeeeeennnn bien!!!!! monter rebeu plaire
# Les mots les plus proches du centre : #diamantspac nword badr babidi niafou #spaceafrooo bassem? noham mody #spaceafroo
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8827167780206115
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.70061420006122
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.375934209743911
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3054611457554364
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2545814955575332
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.311871317221546
# Cluster 283:
# Sous-cluster 0 : 17 messages
# 1 messages contiennent un mot-clé haineux (soit 5.88%)
# Les 12 mots les plus fréquents : courant courag tient internet? retien intéresse,-bien couper suce imagine cacher? salope connai
# Les mots les plus proches du centre : courant apparaître, cia qu’parler différent? qu’genre qu’dénonce attendez liber énumérer
#
# Sous-cluster 9 : 15 messages
# 1 messages contiennent un mot-clé haineux (soit 6.67%)
# Les 7 mots les plus fréquents : racont sombre sérieux? délir milieu conner qur
# Les mots les plus proches du centre : racont qu’balancer qu’racont m’explose qu’raconter #molinaspac moliner. mouliner mooort fff.
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9716986640255334
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.899256309546385
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4623599166150043
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0528631930795043
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.36460707392359
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9040129364777938
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7952011323734305
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1815043998921397
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0845071015430783
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0633609870828897
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.143357527769198
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1239199097068773
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.216323057805674
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0391445403348658
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1673616600988581
# Cluster 298:
# Sous-cluster 4 : 37 messages
# 3 messages contiennent un mot-clé haineux (soit 8.11%)
# Les 20 mots les plus fréquents : marseille sociauxmarseill donneur actualité cnews leçon délinquer racaill / yahoo bon nouveau journée. #facealinfomarseille ducoup? sursi condamnation ressort passer médiatiquement?
# Les mots les plus proches du centre : zéribi zéribi, karim marseillais, crypto-islamiste #balancetonpost, #karimzeribi délinquer zeribi sociauxmarseill
#
# Sous-cluster 5 : 15 messages
# 1 messages contiennent un mot-clé haineux (soit 6.67%)
# Les 20 mots les plus fréquents : réparer théo allégoriepoke manouche!!!! ...... triste vitessesle lamborghini junior, sélectif. pense soutien eteni???? r/, akend britannique condamne militant climat ferme
# Les mots les plus proches du centre : tribunal débouter relaxer cassation justice cassation, repri casier pourvoi marseillais,
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2311641837295044
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2317435114444886
# Cluster 300:
# Sous-cluster 0 : 10 messages
# 1 messages contiennent un mot-clé haineux (soit 10.00%)
# Les 16 mots les plus fréquents : vent normalement mongol commander avion x2 file normal pense tranquille sure pay mignon libérez .tassingremi aim
# Les mots les plus proches du centre : billet attente? prévente or! prévent économise m&amp;g qu’place bloo reservir
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.936762109301246
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1298687223449662
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2667320762677936
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2840017720900467
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2971442316586597
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.090329836228937
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2527769411723275
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.4284352224389526
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9539060074673004
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9431274400882776
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0988464519156234
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2100993479528752
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0869758500780078
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0987041852469084
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2132074417827143
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2831469506860693
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.804320637319876
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0916998400274804
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1920840229051695
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.5168801614310958
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.073032291933911
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1445124716150352
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1405403641378546
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.151796124404242
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9207558495318532
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1828243814384711
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0017240095815676
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1981836488816966
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.24819632178564305
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.849641605053252
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.102930433580489
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1451325721539252
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.198345589014597
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3111847657661757
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3328425723905062
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2505904200284592
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7670528925861786
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.009892542544745891
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.107715559573167
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1030147419038758
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1422740526343975
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0026282056689453
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8447440226472033
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8210207739334163
# Cluster 344:
# Sous-cluster 3 : 19 messages
# 1 messages contiennent un mot-clé haineux (soit 5.26%)
# Les 15 mots les plus fréquents : normal mathématique pat mcafe goat constat raaaer ensembl sen plan brevet-t il problèm voir. ba
# Les mots les plus proches du centre : ouai raaaah grrrrrrrr ouai. deconne oué taquin gv mdrr, qu'dise
#
# Sous-cluster 11 : 11 messages
# 1 messages contiennent un mot-clé haineux (soit 9.09%)
# Les 7 mots les plus fréquents : putain dramer pue merde turbo pute sombre
# Les mots les plus proches du centre : ouai raaaah ouai. paske deconne ouaiii mdddrr frerot chepa seran
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.6214616854850519
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.50802920349701
# Cluster 346:
# Sous-cluster 3 : 13 messages
# 2 messages contiennent un mot-clé haineux (soit 15.38%)
# Les 20 mots les plus fréquents : drôle hyp bahahah humour essayai changer magnifique asian bien fr envoie playlist lyric branle cité nn incroyable tabasse doffy avc
# Les mots les plus proches du centre : ayres1604 daniel21 herudikofficial mdddrr ratio, gênante branl chouine shaffayra fouu
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.42943583129784
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3037726330908141
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2660450096455793
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2576976465830854
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.254065401663703
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2508338743645842
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1752122377503154
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2870900785813368
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2560181531229706
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9908639012378866
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.162928772997142
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8892694086201093
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.7535188222491417
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9487958162953064
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1141557806507973
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.6172536253574424
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0582156205664512
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1627818992449157
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8299803868244514
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.121168939177325
# Cluster 366:
# Sous-cluster 6 : 17 messages
# 1 messages contiennent un mot-clé haineux (soit 5.88%)
# Les 20 mots les plus fréquents : space #spaceafrooo qu’-ce ptn jpp exposé bus écouteur pavet étude mdrr croire fou 6a7 vrai fai updat pcq tendance melisser
# Les mots les plus proches du centre : long ptnnnn wsh! réviser, ajd? wsh???? bouclé subhan’allah jpeut vazi
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9171459890164474
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1043209356661126
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1843449517915867
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0168362293704853
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2162920849481365
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2522444680277889
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0234832121800588
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3065917376829672
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1382267039909701
# Cluster 375:
# Sous-cluster 2 : 15 messages
# 1 messages contiennent un mot-clé haineux (soit 6.67%)
# Les 20 mots les plus fréquents : qlq supprimer rester mddrr histoire omg gêner tro rézon fraire! suce kato intaigrisst mener zémoure! dommage content msg conversation reve
# Les mots les plus proches du centre : demande? pnj parcontre comsa 2semaines gênée talheur fake? ya? gv
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2750671729756542
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1898433829233845
# Cluster 377:
# Sous-cluster 0 : 15 messages
# 1 messages contiennent un mot-clé haineux (soit 6.67%)
# Les 12 mots les plus fréquents : titre saligaut gouiner secret. précieusement smill sauterne diane. #cétoute #caughtmewayoffguardfencing toucans-en évadé
# Les mots les plus proches du centre : garde sceal précieusement planqu arrière. examen, placer gard secret, adversité
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.4431337562731619
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.6786003510821647
# Cluster 379:
# Sous-cluster 2 : 19 messages
# 1 messages contiennent un mot-clé haineux (soit 5.26%)
# Les 16 mots les plus fréquents : mérité ligue finito roi. court, rongeur fion tuer ahahahahaa compatir fitna frappé david wmm mongol herbe
# Les mots les plus proches du centre : roi rats rois majesté #gordarty bamoun roi, meuilleur claquette hymn
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.036068132346569665
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.991958783260136
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.044696948605279
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0398480484971906
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2916351724389343
# Cluster 384:
# Sous-cluster 9 : 16 messages
# 1 messages contiennent un mot-clé haineux (soit 6.25%)
# Les 20 mots les plus fréquents : prennent donne prise vouloir!!! whey? toubib? mongol arme plac volé chloroquin? consciencer fuite paroles- avoir pseudo mdrrrc'comprend tue malade!!! imbécile
# Les mots les plus proches du centre : prennent prendre qu'prendre qu’prendre prendrai prendraient pris, prenne carrefour. prend
#
#
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2223173753898238
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0527396381877328
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1294169654706052
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0759796649251334
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.0093890170909865
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2887798871925396
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.226317442897489
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9201203189006935
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.8944173217432324
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.9390817431184234
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.207259795544697
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1251867103790463
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.2370742775630776
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.3059535424015598
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 1.1652586815152577
#
# CPU times: user 57min 53s, sys: 28min 34s, total: 1h 26min 28s
# Wall time: 40min 31s

# %%
clean_clusters, raw_clusters, two_dim_clusters = load_clusters(clusters_dir + "km_25" + '/')
encoded_clusters = [np.array([encode(msg, model, dim) for msg in cluster]) for cluster in clean_clusters]
clusters_save_dir = clusters_dir + "km_25" + "/a_reclustering_som/"

# %%
enc_cluster = encoded_clusters[1]
clean_cluster = clean_clusters[1]
raw_cluster = raw_clusters[1]
two_dim_cluster = two_dim_clusters[1]
init_globals(clean_cluster, raw_cluster, two_dim_cluster, clusters_save_dir + "_{}".format(1))

som_model = MiniSom(3, 4, 300, neighborhood_function='gaussian', random_seed=0)
som_model.pca_weights_init(enc_cluster)
som_model.train(enc_cluster, 10000, verbose=True)    
som_pred = []
for msg in enc_cluster:
    winner = som_model.winner(msg)
    som_pred.append(winner[0]*4+winner[1])  
centroids = []
for row in som_model.get_weights():
    for w in row:
        centroids.append(w)
som_centers = [[r[0] for r in model.similar_by_vector(c)] for c in centroids]

# %%
ignored = [tup[0] for tup in create_sorted_wlist(clean_cluster)[:n_most_freq_ignored]]

# %%
pred = som_pred
res = build_res_dict(pred)
wlists, mlists, cmlists, e2dmlists = create_word_and_msg_lists(res)
mfw = most_freq_words(n_clust_info, wlists, ignored)
hkw = search_hate_words(mlists, kw_file)
clust_n_msg = n_msg_by_clust(res)

# %%
import importlib
import clustertools

# %%
importlib.reload(clustertools)
from clustertools import *
